# %% [markdown]
# ## MLOps Zoomcamp 2.3 Getting Started with MLflow

# %%
# !python -V
# Out:
# Python 3.12.1

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error, root_mean_squared_error

# %%
import mlflow


mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# 2025/12/15 05:14:27 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/15 05:14:27 INFO mlflow.store.db.utils: Updating database tables
# 2025/12/15 05:14:27 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/15 05:14:27 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2025/12/15 05:14:28 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/15 05:14:28 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# <Experiment: artifact_location='/workspaces/ml-zoomcamp/02-experiment-tracking/mlruns/1', creation_time=1765746754459, experiment_id='1', last_update_time=1765746754459, lifecycle_stage='active', name='nyc-taxi-experiment', tags={'mlflow.experimentKind': 'custom_model_development'}>

# %%
def read_dataframe(filename):
    # df = pd.read_csv(filename)
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
# df_train = read_dataframe('./data/green_tripdata_2021-01.csv')
# df_val = read_dataframe('./data/green_tripdata_2021-02.csv')
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
df_train.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1         2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2         2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3         2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 7         2  2021-01-01 00:26:31   2021-01-01 00:28:50                  N
#
#    RatecodeID PULocationID DOLocationID  passenger_count  trip_distance  \
# 0         1.0           43          151              1.0           1.01
# 1         1.0          166          239              1.0           2.53
# 2         1.0           41           42              1.0           1.12
# 3         1.0          168           75              1.0           1.99
# 7         1.0           75           75              6.0           0.45
#
#    fare_amount  ...  tip_amount  tolls_amount  ehail_fee  \
# 0          5.5  ...        0.00           0.0       None
# 1         10.0  ...        2.81           0.0       None
# 2          6.0  ...        1.00           0.0       None
# 3          8.0  ...        0.00           0.0       None
# 7          3.5  ...        0.96           0.0       None
#
#    improvement_surcharge total_amount  payment_type  trip_type  \
# 0                    0.3         6.80           2.0        1.0
# 1                    0.3        16.86           1.0        1.0
# 2                    0.3         8.30           1.0        1.0
# 3                    0.3         9.30           2.0        1.0
# 7                    0.3         5.76           1.0        1.0
#
#    congestion_surcharge  duration    PU_DO
# 0                  0.00  3.933333   43_151
# 1                  2.75  8.750000  166_239
# 2                  0.00  5.966667    41_42
# 3                  0.00  7.083333   168_75
# 7                  0.00  2.316667    75_75
#
# [5 rows x 22 columns]

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

# mean_squared_error(y_val, y_pred, squared=False)
root_mean_squared_error(y_val, y_pred)
# Out:
# 7.758715206809494

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    # mlflow.set_tag("developer", "cristian")
    mlflow.set_tag("developer", "hayden")

    # mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
    mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.parquet")
    # mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.parquet")

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    # rmse = mean_squared_error(y_val, y_pred, squared=False)
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")

# %% [markdown]
# ## MLOps Zoomcamp 2.3 - Experiment tracking with MLflow

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/hyperopt/atpe.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        # rmse = mean_squared_error(y_val, y_pred, squared=False)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    # 'objective': 'reg:linear',
    'objective': 'reg:squarederror',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=2,  # 50,
    trials=Trials()
)
# Out:
# [0]	validation-rmse:11.46045
# [1]	validation-rmse:10.80054
# [2]	validation-rmse:10.22438
# [3]	validation-rmse:9.71777
# [4]	validation-rmse:9.28097
# [5]	validation-rmse:8.90376
# [6]	validation-rmse:8.57531
# [7]	validation-rmse:8.29713
# [8]	validation-rmse:8.05201
# [9]	validation-rmse:7.84296
# [10]	validation-rmse:7.66476
# [11]	validation-rmse:7.51368
# [12]	validation-rmse:7.38056
# [13]	validation-rmse:7.27250
# [14]	validation-rmse:7.17791
# [15]	validation-rmse:7.09302
# [16]	validation-rmse:7.02438
# [17]	validation-rmse:6.96597
# [18]	validation-rmse:6.91610
# [19]	validation-rmse:6.87063
# [20]	validation-rmse:6.83395
# [21]	validation-rmse:6.79735
# [22]	validation-rmse:6.77000
# [23]	validation-rmse:6.74456
# [24]	validation-rmse:6.72134
# [25]	validation-rmse:6.70237
# [26]	validation-rmse:6.68399
# [27]	validation-rmse:6.66720
# [28]	validation-rmse:6.65408
# [29]	validation-rmse:6.64115
# [30]	validation-rmse:6.62981
# [31]	validation-rmse:6.62155
# [32]	validation-rmse:6.61331
# [33]	validation-rmse:6.60544
# [34]	validation-rmse:6.59953
# [35]	validation-rmse:6.59395
# [36]	validation-rmse:6.58824
# [37]	validation-rmse:6.58364
# [38]	validation-rmse:6.57975
# [39]	validation-rmse:6.57580
# [40]	validation-rmse:6.57173
# [41]	validation-rmse:6.56911
# [42]	validation-rmse:6.56657
# [43]	validation-rmse:6.56390
# [44]	validation-rmse:6.56107
# [45]	validation-rmse:6.55889
# [46]	validation-rmse:6.55675
# [47]	validation-rmse:6.55476
# [48]	validation-rmse:6.55240
# [49]	validation-rmse:6.55069
# [50]	validation-rmse:6.54917
# [51]	validation-rmse:6.54750
# [52]	validation-rmse:6.54649
# [53]	validation-rmse:6.54483
# [54]	validation-rmse:6.54329
# [55]	validation-rmse:6.54202
# [56]	validation-rmse:6.54091
# [57]	validation-rmse:6.53972
# [58]	validation-rmse:6.53825
# [59]	validation-rmse:6.53693
# [60]	validation-rmse:6.53510
# [61]	validation-rmse:6.53414
# [62]	validation-rmse:6.53312
# [63]	validation-rmse:6.53229
# [64]	validation-rmse:6.53164
# [65]	validation-rmse:6.53122
# [66]	validation-rmse:6.53058
# [67]	validation-rmse:6.52989
# [68]	validation-rmse:6.52913
# [69]	validation-rmse:6.52790
# [70]	validation-rmse:6.52710
# [71]	validation-rmse:6.52608
# [72]	validation-rmse:6.52507
# [73]	validation-rmse:6.52451
# [74]	validation-rmse:6.52412
# [75]	validation-rmse:6.52280
# [76]	validation-rmse:6.52187
# [77]	validation-rmse:6.52126
# [78]	validation-rmse:6.52061
# [79]	validation-rmse:6.51950
# [80]	validation-rmse:6.51846
# [81]	validation-rmse:6.51780
# [82]	validation-rmse:6.51661
# [83]	validation-rmse:6.51640
# [84]	validation-rmse:6.51485
# [85]	validation-rmse:6.51423
# [86]	validation-rmse:6.51353
# [87]	validation-rmse:6.51294
# [88]	validation-rmse:6.51234
# [89]	validation-rmse:6.51217
# [90]	validation-rmse:6.51157
# [91]	validation-rmse:6.51098
# [92]	validation-rmse:6.51071
# [93]	validation-rmse:6.50994
# [94]	validation-rmse:6.50944
# [95]	validation-rmse:6.50860
# [96]	validation-rmse:6.50822
# [97]	validation-rmse:6.50743
# [98]	validation-rmse:6.50692
# [99]	validation-rmse:6.50604
# [100]	validation-rmse:6.50567
# [101]	validation-rmse:6.50526
# [102]	validation-rmse:6.50494
# [103]	validation-rmse:6.50442
# [104]	validation-rmse:6.50420
# [105]	validation-rmse:6.50359
# [106]	validation-rmse:6.50297
# [107]	validation-rmse:6.50199
# [108]	validation-rmse:6.50182
# [109]	validation-rmse:6.50078
# [110]	validation-rmse:6.50043
# [111]	validation-rmse:6.49954
# [112]	validation-rmse:6.49904
# [113]	validation-rmse:6.49843
# [114]	validation-rmse:6.49790
# [115]	validation-rmse:6.49746
# [116]	validation-rmse:6.49703
# [117]	validation-rmse:6.49573
# [118]	validation-rmse:6.49518
# [119]	validation-rmse:6.49502
# [120]	validation-rmse:6.49448
# [121]	validation-rmse:6.49424
# [122]	validation-rmse:6.49383
# [123]	validation-rmse:6.49330
# [124]	validation-rmse:6.49301
# [125]	validation-rmse:6.49283
# [126]	validation-rmse:6.49259
# [127]	validation-rmse:6.49234
# [128]	validation-rmse:6.49190
# [129]	validation-rmse:6.49138
# [130]	validation-rmse:6.49125
# [131]	validation-rmse:6.49076
# [132]	validation-rmse:6.49065
# [133]	validation-rmse:6.48977
# [134]	validation-rmse:6.48923
# [135]	validation-rmse:6.48847
# [136]	validation-rmse:6.48804
# [137]	validation-rmse:6.48725
# [138]	validation-rmse:6.48695
# [139]	validation-rmse:6.48652
# [140]	validation-rmse:6.48607
# [141]	validation-rmse:6.48609
# [142]	validation-rmse:6.48514
# [143]	validation-rmse:6.48458
# [144]	validation-rmse:6.48413
# [145]	validation-rmse:6.48371
# [146]	validation-rmse:6.48332
# [147]	validation-rmse:6.48286
# [148]	validation-rmse:6.48269
# [149]	validation-rmse:6.48267
# [150]	validation-rmse:6.48239
# [151]	validation-rmse:6.48187
# [152]	validation-rmse:6.48172
# [153]	validation-rmse:6.48136
# [154]	validation-rmse:6.48066
# [155]	validation-rmse:6.48042
# [156]	validation-rmse:6.47971
# [157]	validation-rmse:6.47962
# [158]	validation-rmse:6.47946
# [159]	validation-rmse:6.47893
# [160]	validation-rmse:6.47849
# [161]	validation-rmse:6.47805
# [162]	validation-rmse:6.47776
# [163]	validation-rmse:6.47740
# [164]	validation-rmse:6.47702
# [165]	validation-rmse:6.47633
# [166]	validation-rmse:6.47570
# [167]	validation-rmse:6.47547
# [168]	validation-rmse:6.47524
# [169]	validation-rmse:6.47509
# [170]	validation-rmse:6.47480
# [171]	validation-rmse:6.47445
# [172]	validation-rmse:6.47415
# [173]	validation-rmse:6.47398
# [174]	validation-rmse:6.47368
# [175]	validation-rmse:6.47334
# [176]	validation-rmse:6.47302
# [177]	validation-rmse:6.47282
# [178]	validation-rmse:6.47250
# [179]	validation-rmse:6.47220
# [180]	validation-rmse:6.47185
# [181]	validation-rmse:6.47158
# [182]	validation-rmse:6.47105
# [183]	validation-rmse:6.47070
# [184]	validation-rmse:6.47075
# [185]	validation-rmse:6.47039
# [186]	validation-rmse:6.47012
# [187]	validation-rmse:6.46966
# [188]	validation-rmse:6.46948
# [189]	validation-rmse:6.46941
# [190]	validation-rmse:6.46915
# [191]	validation-rmse:6.46858
# [192]	validation-rmse:6.46826
# [193]	validation-rmse:6.46774
# [194]	validation-rmse:6.46749
# [195]	validation-rmse:6.46640
# [196]	validation-rmse:6.46558
# [197]	validation-rmse:6.46537
# [198]	validation-rmse:6.46498
# [199]	validation-rmse:6.46486
# [200]	validation-rmse:6.46480
# [201]	validation-rmse:6.46451
# [202]	validation-rmse:6.46423
# [203]	validation-rmse:6.46392
# [204]	validation-rmse:6.46332
# [205]	validation-rmse:6.46314
# [206]	validation-rmse:6.46273
# [207]	validation-rmse:6.46240
# [208]	validation-rmse:6.46216
# [209]	validation-rmse:6.46185
# [210]	validation-rmse:6.46150
# [211]	validation-rmse:6.46112
# [212]	validation-rmse:6.46094
# [213]	validation-rmse:6.46095
# [214]	validation-rmse:6.46050
# [215]	validation-rmse:6.46027
# [216]	validation-rmse:6.45999
# [217]	validation-rmse:6.45981
# [218]	validation-rmse:6.45954
# [219]	validation-rmse:6.45897
# [220]	validation-rmse:6.45861
# [221]	validation-rmse:6.45817
# [222]	validation-rmse:6.45797
# [223]	validation-rmse:6.45752
# [224]	validation-rmse:6.45751
# [225]	validation-rmse:6.45730
# [226]	validation-rmse:6.45735
# [227]	validation-rmse:6.45696
# [228]	validation-rmse:6.45674
# [229]	validation-rmse:6.45632
# [230]	validation-rmse:6.45560
# [231]	validation-rmse:6.45539
# [232]	validation-rmse:6.45516
# [233]	validation-rmse:6.45492
# [234]	validation-rmse:6.45462
# [235]	validation-rmse:6.45407
# [236]	validation-rmse:6.45380
# [237]	validation-rmse:6.45352
# [238]	validation-rmse:6.45353
# [239]	validation-rmse:6.45337
# [240]	validation-rmse:6.45364
# [241]	validation-rmse:6.45346
# [242]	validation-rmse:6.45318
# [243]	validation-rmse:6.45311
# [244]	validation-rmse:6.45285
# [245]	validation-rmse:6.45259
# [246]	validation-rmse:6.45218
# [247]	validation-rmse:6.45207
# [248]	validation-rmse:6.45176
# [249]	validation-rmse:6.45197
# [250]	validation-rmse:6.45075
# [251]	validation-rmse:6.45057
# [252]	validation-rmse:6.45041
# [253]	validation-rmse:6.45019
# [254]	validation-rmse:6.45006
# [255]	validation-rmse:6.44973
# [256]	validation-rmse:6.44958
# [257]	validation-rmse:6.44952
# [258]	validation-rmse:6.44937
# [259]	validation-rmse:6.44929
# [260]	validation-rmse:6.44922
# [261]	validation-rmse:6.44888
# [262]	validation-rmse:6.44853
# [263]	validation-rmse:6.44822
# [264]	validation-rmse:6.44785
# [265]	validation-rmse:6.44777
# [266]	validation-rmse:6.44744
# [267]	validation-rmse:6.44727
# [268]	validation-rmse:6.44710
# [269]	validation-rmse:6.44666
# [270]	validation-rmse:6.44633
# [271]	validation-rmse:6.44613
# [272]	validation-rmse:6.44575
# [273]	validation-rmse:6.44537
# [274]	validation-rmse:6.44543
# [275]	validation-rmse:6.44530
# [276]	validation-rmse:6.44511
# [277]	validation-rmse:6.44516
# [278]	validation-rmse:6.44481
# [279]	validation-rmse:6.44447
# [280]	validation-rmse:6.44419
# [281]	validation-rmse:6.44418
# [282]	validation-rmse:6.44425
# [283]	validation-rmse:6.44402
# [284]	validation-rmse:6.44379
# [285]	validation-rmse:6.44373
# [286]	validation-rmse:6.44367
# [287]	validation-rmse:6.44359
# [288]	validation-rmse:6.44339
# [289]	validation-rmse:6.44328
# [290]	validation-rmse:6.44303
# [291]	validation-rmse:6.44277
# [292]	validation-rmse:6.44245
# [293]	validation-rmse:6.44235
# [294]	validation-rmse:6.44225
# [295]	validation-rmse:6.44199
# [296]	validation-rmse:6.44175
# [297]	validation-rmse:6.44157
# [298]	validation-rmse:6.44165
# [299]	validation-rmse:6.44119
# [300]	validation-rmse:6.44089
# ...
# [850]	validation-rmse:6.62393
# [851]	validation-rmse:6.62406
# [852]	validation-rmse:6.62405
# [853]	validation-rmse:6.62407
# [854]	validation-rmse:6.62402
# [855]	validation-rmse:6.62399
# [856]	validation-rmse:6.62399
# [857]	validation-rmse:6.62405
# [858]	validation-rmse:6.62405
# [859]	validation-rmse:6.62413
# [860]	validation-rmse:6.62405
# [861]	validation-rmse:6.62405
# [862]	validation-rmse:6.62406
# [863]	validation-rmse:6.62405
# [864]	validation-rmse:6.62404
# [865]	validation-rmse:6.62397
# [866]	validation-rmse:6.62395
# [867]	validation-rmse:6.62400
# [868]	validation-rmse:6.62394
# [869]	validation-rmse:6.62396
# [870]	validation-rmse:6.62392
# [871]	validation-rmse:6.62394
# [872]	validation-rmse:6.62398
# [873]	validation-rmse:6.62389
# [874]	validation-rmse:6.62395
# [875]	validation-rmse:6.62395
# [876]	validation-rmse:6.62404
# [877]	validation-rmse:6.62397
# [878]	validation-rmse:6.62400
# [879]	validation-rmse:6.62401
# [880]	validation-rmse:6.62398
# [881]	validation-rmse:6.62398
# [882]	validation-rmse:6.62393
# [883]	validation-rmse:6.62388
# [884]	validation-rmse:6.62388
# [885]	validation-rmse:6.62391
# [886]	validation-rmse:6.62376
# [887]	validation-rmse:6.62375
# [888]	validation-rmse:6.62368
# [889]	validation-rmse:6.62384
# [890]	validation-rmse:6.62391
# [891]	validation-rmse:6.62391
# [892]	validation-rmse:6.62383
# [893]	validation-rmse:6.62382
# [894]	validation-rmse:6.62369
# [895]	validation-rmse:6.62370
# [896]	validation-rmse:6.62367
# [897]	validation-rmse:6.62363
# [898]	validation-rmse:6.62363
# [899]	validation-rmse:6.62371
# [900]	validation-rmse:6.62375
# [901]	validation-rmse:6.62377
# [902]	validation-rmse:6.62378
# [903]	validation-rmse:6.62382
# [904]	validation-rmse:6.62387
# [905]	validation-rmse:6.62401
# [906]	validation-rmse:6.62402
# [907]	validation-rmse:6.62395
# [908]	validation-rmse:6.62405
# [909]	validation-rmse:6.62397
# [910]	validation-rmse:6.62400
# [911]	validation-rmse:6.62405
# [912]	validation-rmse:6.62402
# [913]	validation-rmse:6.62390
# [914]	validation-rmse:6.62386
# [915]	validation-rmse:6.62389
# [916]	validation-rmse:6.62392
# [917]	validation-rmse:6.62399
# [918]	validation-rmse:6.62395
# [919]	validation-rmse:6.62406
# [920]	validation-rmse:6.62402
# [921]	validation-rmse:6.62405
# [922]	validation-rmse:6.62400
# [923]	validation-rmse:6.62398
# [924]	validation-rmse:6.62394
# [925]	validation-rmse:6.62395
# [926]	validation-rmse:6.62399
# [927]	validation-rmse:6.62403
# [928]	validation-rmse:6.62391
# [929]	validation-rmse:6.62386
# [930]	validation-rmse:6.62389
# [931]	validation-rmse:6.62389
# [932]	validation-rmse:6.62390
# [933]	validation-rmse:6.62389
# [934]	validation-rmse:6.62381
# [935]	validation-rmse:6.62381
# [936]	validation-rmse:6.62383
# [937]	validation-rmse:6.62377
# [938]	validation-rmse:6.62385
# [939]	validation-rmse:6.62385
# [940]	validation-rmse:6.62387
# [941]	validation-rmse:6.62390
# [942]	validation-rmse:6.62391
# [943]	validation-rmse:6.62390
# [944]	validation-rmse:6.62387
# [945]	validation-rmse:6.62388
# [946]	validation-rmse:6.62395
# [947]	validation-rmse:6.62397
# [948]	validation-rmse:6.62394
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 2/2 [09:03<00:00, 271.56s/trial, best loss: 6.401792144152523]

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
